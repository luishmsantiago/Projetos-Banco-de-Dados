# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.med.umich.edu/lrc/anatomy-tables/brain.html'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')
tables = soup.find_all('table')

# %%
def generate_df(table):
    lines = []
    for i, row in enumerate(table.find_all('tr')[1:]):
        elem = 'th' if i == 0 else 'td'
        line = [row.text for row in row.find_all(elem)[:5]]
        lines.append(line)

    return pd.DataFrame(lines[1:], columns=lines[0])

# %%
#tables[1].find_all('tr')[5].find_all('td')[:3]

# %%
names = ['meningeal_ventricular_system',]
dfs = {name: generate_df(tables[i]) for i, name in enumerate(names, start=1)}

# %%
df2 = dfs['meningeal_ventricular_system'].copy() #.head(3)
df2
# Out:
#                      Structure  \
# 0              arachnoid mater
# 1                     meninges
# 2                   dura mater
# 3          dura mater, cranial
# 4           dura mater, spinal
# 5               epidural space
# 6           subarachnoid space
# 7                    pia mater
# 8        denticulate ligament
# 9     filum terminale internum
# 10    filum terminale externum
# 11          ventricle, lateral
# 12            ventricle, third
# 13           ventricle, fourth
# 14              choroid plexus
# 15              tela choroidea
# 16   interventricular foramina
# 17           cerebral aqueduct
# 18            median aperature
# 19           lateral aperature
# 20    central canal of medulla
# 21             pontine cistern
# 22     interpeduncular cistern
# 23  cerebellomedullary cistern
# 24              lumbar cistern
# 25                falx cerebri
# 26              falx cerebelli
# 27         tentorium cerebelli
# 28           diaphragma sellae
# ...
