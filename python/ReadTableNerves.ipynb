# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.med.umich.edu/lrc/anatomy-tables/nerves_alpha.html'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')
tables = soup.find_all('table')

# %%
def generate_df(table):
    lines = []
    for i, row in enumerate(table.find_all('tr')[1:]):
        elem = 'th' if i == 0 else 'td'
        line = [row.text for row in row.find_all(elem)[:6]]
        lines.append(line)

    return pd.DataFrame(lines[1:], columns=lines[0])

# %%
tables[1].find_all('tr')[5].find_all('td')[:6]

# %%
names = ['']
dfs = {name: generate_df(tables[i]) for i, name in enumerate(names, start=1)}

# %%
df2 = dfs[''].copy() #.head(3)
df2
# Out:
#                            Nerve  \
# 0                       abducens
# 1                      accessory
# 2    alveolar, anterior superior
# 3             alveolar, inferior
# 4      alveolar, middle superior
# ..                           ...
# 351         vestibulocochlear n.
# 352      white ramus communicans
# 353                 zygomatic n.
# 354          zygomaticofacial n.
# 355        zygomaticotemporal n.
#
#                                                 Source  \
# 0                               pons: abducens nucleus
# 1    cranial root: medulla - nucleus ambiguus; spin...
# 2                                      infraorbital n.
# 3         mandibular division of the trigeminal n.(V3)
# 4                                      infraorbital n.
# ..                                                 ...
# 351  pons & medulla: vestibular nuclei from the ves...
# 352  cell bodies located in the lateral horn gray m...
# 353       maxillary division of the trigeminal n. (V2)
# 354  zygomatic from the maxillary division of the t...
# 355  zygomatic from the maxillary division of the t...
#
#                                               Branches  \
# 0                                    no named branches
# 1                                    no named branches
# 2                                        dental plexus
# 3    n. to mylohyoid; inferior dental plexus; menta...
# 4                                        dental plexus
# ..                                                 ...
# 351  divides within the temporal bone into vestibul...
# 352                                               none
# 353              zygomaticofacial & zygomaticotemporal
# 354                                  no named branches
# 355                                  communicating br.
#
#                                                  Motor  \
# 0                               GSE: lateral rectus m.
# 1           GSE: sternocleidomastoid and trapezius mm.
# 2                                                 none
# 3    mylohyoid muscle and anterior belly of the dig...
# 4                                                 none
# ..                                                 ...
# 351                                               none
# 352  axons contained within white rami communicante...
# 353                        carries secretomotor fibers
# 354                                               none
# 355                        carries secretomotor fibers
#
#                                                Sensory  \
# 0                                                 none
# 1                                                 none
# 2    maxillary canine and incisor teeth and gingiva...
# 3              teeth of the mandible; skin of the chin
# 4    maxillary premolar teeth and gingiva; maxillar...
# ..                                                 ...
# 351  vestibular: balance/proprioception (SSA); coch...
# 352  pain from viscera is carried back to the spina...
# 353  skin of the face lateral and superior to the o...
# 354                  skin of face lateral to the orbit
# 355            skin of face superolateral to the orbit
#
#                                                  Notes
# 0    also known as: CN VI, 6th cranial nerve; passe...
# 1    also known as: CN XI, 11th cranial nerve; spin...
# 2    anterior superior alveolar n. is enclosed in b...
# 3    inferior alveolar n. passes through the mandib...
# 4    middle superior alveolar n. is enclosed in bon...
# ..                                                 ...
# 351  also known as: CN VIII, 8th cranial nerve; aud...
# 352  white rami communicantes connect the sympathet...
# 353  zygomatic n. carries postganglionic parasympat...
# 354  zygomaticofacial n. passes through the zygomat...
# 355  zygomaticotemporal n. carries postganglionic p...
#
# [356 rows x 6 columns]
